# %% [markdown]
# # Image Scraper Project

# %% [markdown]
# ## Image Scraper

# %% [markdown]
# ![Image%20Scrapper.jpg](attachment:Image%20Scrapper.jpg)

# %% [markdown]
# ## 1st Image

# %% [markdown]
# ![1st%20Image.jpg](attachment:1st%20Image.jpg)

# %% [markdown]
# # 2nd Image

# %% [markdown]
# ![2nd%20Image.jpg](attachment:2nd%20Image.jpg)

# %% [markdown]
# # 3rd Image

# %% [markdown]
# ![3rd%20Image.jpg](attachment:3rd%20Image.jpg)

# %% [markdown]
# # 4th Image

# %% [markdown]
# ![4th%20Image.jpg](attachment:4th%20Image.jpg)

# %% [markdown]
# # 5th Image

# %% [markdown]
# ![5th%20Image.jpg](attachment:5th%20Image.jpg)
